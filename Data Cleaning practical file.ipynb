# %% [markdown]
# # TASK - 4: Demonstrate Data Cleaning

# %% [markdown]
# Data Cleaning means the process of identifying the incorrect, incomplete, inaccurate, irrelevant or missing part of the data and then modifying, replacing or deleting them according to the necessity. Data cleaning is considered a foundational element of the basic data science.

# %% [markdown]
# ### Different Ways of Cleaning Data

# %% [markdown]
# # 1. Inconsistent column

# %% [markdown]
# If your DataFrame contains columns that are irrelevant or you are never going to use them then you can drop them to give more focus on the columns you will work on.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data={    'Name':['A','B','C','D','E','F','G','H'],
                'Height':[5.2,5.7,5.6,5.5,5.3,5.8,5.6,5.5],
                'Roll':[55,99,15,80,1,12,47,104],
                'Department':['CSE','EEE','BME','CSE','ME','ME','CE','CSE'],
                'Address':['polashi','banani','farmgate','mirpur','dhanmondi','ishwardi','khulna','uttara']}

# %%
df=pd.DataFrame(data)
print(df)
# Out:
#   Name  Height  Roll Department    Address
# 0    A     5.2    55        CSE    polashi
# 1    B     5.7    99        EEE     banani
# 2    C     5.6    15        BME   farmgate
# 3    D     5.5    80        CSE     mirpur
# 4    E     5.3     1         ME  dhanmondi
# 5    F     5.8    12         ME   ishwardi
# 6    G     5.6    47         CE     khulna
# 7    H     5.5   104        CSE     uttara

# %%
df.drop('Height', axis=1)
# or 
# df.drop(columns='Height')
# Out:
#   Name  Roll Department    Address
# 0    A    55        CSE    polashi
# 1    B    99        EEE     banani
# 2    C    15        BME   farmgate
# 3    D    80        CSE     mirpur
# 4    E     1         ME  dhanmondi
# 5    F    12         ME   ishwardi
# 6    G    47         CE     khulna
# 7    H   104        CSE     uttara

# %% [markdown]
# # 2. Missing data

# %% [markdown]
# If you find missing values in your dataset you must handle it. If you find any missing values in the dataset you can perform any of these three task on it:
#
# 1.Leave as it is
# 2.Filling the missing values
# 3.Drop them For filling the missing values we can perform different    methods.

# %%
df2= pd.read_excel('Salary_Data.xlsx')

# %%
df2
# Out:
#     YearsExperience   Age    Salary
# 0               1.1  21.0   39343.0
# 1               1.3  21.5   46205.0
# 2               1.5   NaN   37731.0
# 3               2.0  22.0   43525.0
# 4               2.2  22.2   39891.0
# 5               2.9  23.0   56642.0
# 6               NaN  23.0       NaN
# 7               3.2  23.3   54445.0
# 8               3.2  23.3   64445.0
# 9               3.7  23.6   57189.0
# 10              3.9  23.9   63218.0
# 11              NaN  24.0   55794.0
# 12              4.0  24.0   56957.0
# 13              4.1  24.0       NaN
# 14              4.5  25.0   61111.0
# 15              4.9  25.0   67938.0
# 16              5.1  26.0   66029.0
# 17              5.3  27.0   83088.0
# 18              5.9  28.0   81363.0
# 19              6.0  29.0   93940.0
# 20              NaN  30.0   91738.0
# 21              7.1  30.0   98273.0
# 22              7.9  31.0  101302.0
# 23              8.2  32.0  113812.0
# 24              8.7  33.0  109431.0
# 25              9.0  34.0  105582.0
# 26              9.5  35.0  116969.0
# 27              9.6  36.0  112635.0
# 28             10.3  37.0  122391.0
# 29             10.5  38.0  121872.0

# %%
df2['YearsExperience']=df2['YearsExperience'].fillna(df2.YearsExperience.mean())

# %%
df2
# Out:
#     YearsExperience   Age    Salary
# 0          1.100000  21.0   39343.0
# 1          1.300000  21.5   46205.0
# 2          1.500000   NaN   37731.0
# 3          2.000000  22.0   43525.0
# 4          2.200000  22.2   39891.0
# 5          2.900000  23.0   56642.0
# 6          5.392593  23.0       NaN
# 7          3.200000  23.3   54445.0
# 8          3.200000  23.3   64445.0
# 9          3.700000  23.6   57189.0
# 10         3.900000  23.9   63218.0
# 11         5.392593  24.0   55794.0
# 12         4.000000  24.0   56957.0
# 13         4.100000  24.0       NaN
# 14         4.500000  25.0   61111.0
# 15         4.900000  25.0   67938.0
# 16         5.100000  26.0   66029.0
# 17         5.300000  27.0   83088.0
# 18         5.900000  28.0   81363.0
# 19         6.000000  29.0   93940.0
# 20         5.392593  30.0   91738.0
# 21         7.100000  30.0   98273.0
# 22         7.900000  31.0  101302.0
# 23         8.200000  32.0  113812.0
# 24         8.700000  33.0  109431.0
# 25         9.000000  34.0  105582.0
# 26         9.500000  35.0  116969.0
# 27         9.600000  36.0  112635.0
# 28        10.300000  37.0  122391.0
# 29        10.500000  38.0  121872.0

# %% [markdown]
# You can also drop the rows or columns where missing values are found. we drop the rows containing missing values. Here You can drop missing values with the help of pandas.DataFrame.dropna.

# %%
df2= df2.dropna()

# %%
df2.isnull().sum(axis=0)
# Out:
# YearsExperience    0
# Age                0
# Salary             0
# dtype: int64

# %% [markdown]
# # OUTLIERS

# %% [markdown]
# “In statistics, an outlier is a data point that differs significantly from other observations.”

# %%
df3= pd.read_excel('student_info.xlsx')
df3
# Out:
#    study_hours  student_marks
# 0         6.83          78.50
# 1         6.56          76.74
# 2         5.70          78.90
# 3         5.67          71.82
# 4         8.67          84.19
# 5         7.55          81.18

# %%
X=df3.study_hours
y=df3.student_marks
plt.scatter(X,y)

# %%
df_removed_outliers = df3[df3.student_marks>72]

# %%
df_removed_outliers
# Out:
#    study_hours  student_marks
# 0         6.83          78.50
# 1         6.56          76.74
# 2         5.70          78.90
# 4         8.67          84.19
# 5         7.55          81.18

# %% [markdown]
# ## Duplicate rows:

# %% [markdown]
# To delete the duplicate rows you can use — dataset_name.drop_duplicates()

# %%
df4= pd.read_excel('student_info1.xlsx')

# %%
df4
# Out:
#   Name  Height  Roll
# 0    A     5.2    55
# 1    A     5.2    55
# 2    c     5.6    15
# 3    D     5.5    80
# 4    E     5.3    12
# 5    E     5.3    12
# 6    G     5.6    47
# 7    H     5.5   104

# %%
df4.drop_duplicates()
# Out:
#   Name  Height  Roll
# 0    A     5.2    55
# 2    c     5.6    15
# 3    D     5.5    80
# 4    E     5.3    12
# 6    G     5.6    47
# 7    H     5.5   104

# %% [markdown]
# ## Data Concatenation

# %%
df5= pd.read_excel('student_info1.xlsx')
df5
# Out:
#   Name  Height  Roll
# 0    A     5.2    55
# 1    A     5.2    55
# 2    c     5.6    15
# 3    D     5.5    80
# 4    E     5.3    12
# 5    E     5.3    12
# 6    G     5.6    47
# 7    H     5.5   104

# %%
df6= pd.read_excel('student_info.xlsx')
df6
# Out:
#    study_hours  student_marks
# 0         6.83          78.50
# 1         6.56          76.74
# 2         5.70          78.90
# 3         5.67          71.82
# 4         8.67          84.19
# 5         7.55          81.18

# %%
df7= pd.concat([df5, df6])
df7
# Out:
#   Name  Height   Roll  study_hours  student_marks
# 0    A     5.2   55.0          NaN            NaN
# 1    A     5.2   55.0          NaN            NaN
# 2    c     5.6   15.0          NaN            NaN
# 3    D     5.5   80.0          NaN            NaN
# 4    E     5.3   12.0          NaN            NaN
# 5    E     5.3   12.0          NaN            NaN
# 6    G     5.6   47.0          NaN            NaN
# 7    H     5.5  104.0          NaN            NaN
# 0  NaN     NaN    NaN         6.83          78.50
# 1  NaN     NaN    NaN         6.56          76.74
# 2  NaN     NaN    NaN         5.70          78.90
# 3  NaN     NaN    NaN         5.67          71.82
# 4  NaN     NaN    NaN         8.67          84.19
# 5  NaN     NaN    NaN         7.55          81.18
